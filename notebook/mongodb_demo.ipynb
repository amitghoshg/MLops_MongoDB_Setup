# %%
# Check which Python (environmet) executable is being used
# import sys
# print(sys.executable)
# Out:
# g:\Job Prepartion\Courses\Practice_1\MLops_MongoDB_Setup\.venv\Scripts\python.exe

# %%
import pandas as pd
import pymongo
import certifi

# 1. Load CSV into a DataFrame
df = pd.read_csv("data.csv")

# 2. Convert DataFrame to list of dictionaries (standard for MongoDB)
data_dict = df.to_dict(orient="records")

# 3. Setup Connection
# note:  user name = aghoshdme_db_user   &      password = B3uXZvlgmZ4mxGb1
uri = "mongodb+srv://aghoshdme_db_user:B3uXZvlgmZ4mxGb1@cluster0.qsxmrds.mongodb.net/?appName=Cluster0"
client = pymongo.MongoClient(uri, tlsCAFile=certifi.where())

# 4. Access Cluster > Database > Collection
db = client["project_1"]
collection = db["vehicle"]

# 5. Insert Data
result = collection.insert_many(data_dict)
print(f"Successfully inserted {len(result.inserted_ids)} records.")
# Out:
# Successfully inserted 381109 records.
